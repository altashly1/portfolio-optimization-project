# %%
# We explicitly add the packages needed for the robust optimization
using Pkg
Pkg.add([
    "JuMP",         # The modeling language
    "COSMO",        # A solver for SOCPs
    "CSV",          # For reading data
    "DataFrames",   # For handling data
    "JLD2",         # For loading .jld2 files
    "Plots",        # For plotting
    "Statistics",   # For mean, std
    "LinearAlgebra",# For matrix math (norm, sqrt, I)
    "PrettyTables"  # For nice output
])

# Load all the packages
using JuMP
using COSMO
using CSV
using DataFrames
using JLD2
using Plots
using Statistics
using LinearAlgebra
using PrettyTables
